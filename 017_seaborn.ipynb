# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
bill = df["total_bill"]
plt.plot(bill)
plt.show()

# %%
# sns.lineplot(df["total_bill"])
# sns.scatterplot(df["total_bill"])
sns.scatterplot(x = "total_bill", y = "tip", data = df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(df["total_bill"], color = "green", edgecolor = "red")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.barplot(x = "day", y = "total_bill", data = df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.kdeplot(df["total_bill"])           # density plot
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# sns --> 

# categorical --->  
# numerical ---> scatterplot, lineplot --- relational --- relplot

# %%
sns.relplot(x = "total_bill", y = "tip", data = df)    # default --> scatterplot
sns.relplot(x = "total_bill", y = "tip", data = df, kind = "line")

# %%
# sns.relplot(x = "total_bill", y = "tip", data = df, kind = "scatter", hue = "day")
# sns.relplot(x = "total_bill", y = "tip", data = df, kind = "scatter", hue = "size")
sns.relplot(x = "total_bill", y = "tip", data = df, 
kind = "scatter", 
hue = "smoker", 
style = "size",
col = "day",
# row = "day",
)

# %%
sns.catplot(x = "day", y = "total_bill", data = df, kind = "swarm")   #swarm avoides over lapping

# %%
sns.countplot(x = "day", data = df)   #count is already defined in catplot
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.barplot(x = "day", y = "total_bill", data = df, estimator = "mean")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# pointplot --> shows the mean os data connecter bu trend

sns.pointplot(x = "day", y = "total_bill", data = df, hue = "sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#boxplot --> spresd of data in the form of box

sns.boxplot(x = "day", y = "total_bill", data = df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# violinplot --> spread of data in the form of violin

sns.violinplot(x = "day", y = "total_bill", data = df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pairplot(df)

# %%
sns.histplot(df["tip"], kde = True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.boxplot(df["tip"])
# Out:
# <Axes: ylabel='tip'>

# %%
sns.boxplot(df["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %%
# percentile handle

q1 = df["total_bill"].quantile(0.25)
q3 = df["total_bill"].quantile(0.75)
iqr = q3-q1
lower_limit = q1 - 1.5*iqr
upper_limit = q3 + 1.5*iqr

print(lower_limit, upper_limit)

df[df["total_bill"] < lower_limit]
df[df["total_bill"] > upper_limit]

df = df[(df["total_bill"] > lower_limit) & (df["total_bill"] < upper_limit)]
sns.boxplot(df["total_bill"])
# Out:
# -2.8224999999999945 40.29749999999999
# <Axes: ylabel='total_bill'>
